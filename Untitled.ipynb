# %% [markdown]
# # IMPORTING ALL THE LIBRARIES

# %%
import cv2
import pytesseract
from pytesseract import Output
import matplotlib.pyplot as plt
from PIL import Image
import import_ipynb
import numpy as np
import os
import glob

# %% [markdown]
# # SETTING UP THE PYTESSERACT PATH

# %%
pytesseract.pytesseract.tesseract_cmd = r'C:\Program Files\Tesseract-OCR\tesseract.exe'

# %% [markdown]
# # SETTING UP THE DYSLEXIC AND NON DYSLEXIC IMAGE DIRECTORY

# %%
image_directory_dyslexic = './data/dyslexic'

image_directory_non_dyslexic = './data/non_dyslexic' 

image_files_dy = glob.glob(os.path.join(image_directory_dyslexic, '*.jpg')) + glob.glob(os.path.join(image_directory_dyslexic, '*.png'))
image_files_non_dy = glob.glob(os.path.join(image_directory_non_dyslexic, '*.jpg')) + glob.glob(os.path.join(image_directory_non_dyslexic, '*.png'))

# %% [markdown]
# # PRINTING THE FETCHED IMAGES DIR

# %%
print(image_files_dy)
# Out:
# ['./data/dyslexic\\1.jpg', './data/dyslexic\\10.jpg', './data/dyslexic\\11.jpg', './data/dyslexic\\12.jpg', './data/dyslexic\\13.jpg', './data/dyslexic\\14.jpg', './data/dyslexic\\15.jpg', './data/dyslexic\\16.jpg', './data/dyslexic\\17.jpg', './data/dyslexic\\18.jpg', './data/dyslexic\\19.jpg', './data/dyslexic\\2.jpg', './data/dyslexic\\20.jpg', './data/dyslexic\\21.jpg', './data/dyslexic\\22.jpg', './data/dyslexic\\23.jpg', './data/dyslexic\\24.jpg', './data/dyslexic\\25.jpg', './data/dyslexic\\26.jpg', './data/dyslexic\\27.jpg', './data/dyslexic\\28.jpg', './data/dyslexic\\29.jpg', './data/dyslexic\\3.jpg', './data/dyslexic\\30.jpg', './data/dyslexic\\31.jpg', './data/dyslexic\\32.jpg', './data/dyslexic\\33.jpg', './data/dyslexic\\34.jpg', './data/dyslexic\\35.jpg', './data/dyslexic\\36.jpg', './data/dyslexic\\37.jpg', './data/dyslexic\\38.jpg', './data/dyslexic\\39.jpg', './data/dyslexic\\4.jpg', './data/dyslexic\\40.jpg', './data/dyslexic\\41.jpg', './data/dyslexic\\42.jpg', './data/dyslexic\\43.jpg', './data/dyslexic\\44.jpg', './data/dyslexic\\45.jpg', './data/dyslexic\\46.jpg', './data/dyslexic\\47.jpg', './data/dyslexic\\48.jpg', './data/dyslexic\\49.jpg', './data/dyslexic\\5.jpg', './data/dyslexic\\50.jpg', './data/dyslexic\\6.jpg', './data/dyslexic\\7.jpg', './data/dyslexic\\8.jpg', './data/dyslexic\\9.jpg']

# %%
print(image_files_non_dy)
# Out:
# ['./data/non_dyslexic\\1.jpg', './data/non_dyslexic\\10.jpg', './data/non_dyslexic\\11.jpg', './data/non_dyslexic\\12.jpg', './data/non_dyslexic\\13.jpg', './data/non_dyslexic\\14.jpg', './data/non_dyslexic\\15.jpg', './data/non_dyslexic\\16.jpg', './data/non_dyslexic\\17.jpg', './data/non_dyslexic\\18.jpg', './data/non_dyslexic\\19.jpg', './data/non_dyslexic\\2.jpg', './data/non_dyslexic\\20.jpg', './data/non_dyslexic\\21.jpg', './data/non_dyslexic\\22.jpg', './data/non_dyslexic\\23.jpg', './data/non_dyslexic\\24.jpg', './data/non_dyslexic\\25.jpg', './data/non_dyslexic\\26.jpg', './data/non_dyslexic\\27.jpg', './data/non_dyslexic\\28.jpg', './data/non_dyslexic\\29.jpg', './data/non_dyslexic\\3.jpg', './data/non_dyslexic\\30.jpg', './data/non_dyslexic\\31.jpg', './data/non_dyslexic\\32.jpg', './data/non_dyslexic\\33.jpg', './data/non_dyslexic\\34.jpg', './data/non_dyslexic\\35.jpg', './data/non_dyslexic\\36.jpg', './data/non_dyslexic\\37.jpg', './data/non_dyslexic\\38.jpg', './data/non_dyslexic\\39.jpg', './data/non_dyslexic\\4.jpg', './data/non_dyslexic\\40.jpg', './data/non_dyslexic\\41.jpg', './data/non_dyslexic\\42.jpg', './data/non_dyslexic\\43.jpg', './data/non_dyslexic\\44.jpg', './data/non_dyslexic\\45.jpg', './data/non_dyslexic\\46.jpg', './data/non_dyslexic\\47.jpg', './data/non_dyslexic\\48.jpg', './data/non_dyslexic\\49.jpg', './data/non_dyslexic\\5.jpg', './data/non_dyslexic\\50.jpg', './data/non_dyslexic\\6.jpg', './data/non_dyslexic\\7.jpg', './data/non_dyslexic\\8.jpg', './data/non_dyslexic\\9.jpg']

# %% [markdown]
# # Sample Extraction

# %% [markdown]
# # Visualizing the image

# %%
image_path = './data/non_dyslexic/10.jpg'
img = Image.open(image_path)

# %%
# print metadata
print(f"Random image path: {image_path}")
print(f"Image height: {img.height}")
print(f"Image width: {img.width}")
img
# Out:
# Random image path: ./data/non_dyslexic/10.jpg
# Image height: 280
# Image width: 493
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=493x280>

# %%
def preprocess_image(image):
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    cv2.imshow('Grayscale Image', gray_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    cv2.imshow('Blurred Image', blurred_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    threshold_image = cv2.adaptiveThreshold(blurred_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
    cv2.imshow('Threshold Image', threshold_image)
    cv2.waitKey(0)
    cv2.destroyAllWindows()
    
    return gray_image

# %%
image_path = './data/non_dyslexic/10.jpg'

image = cv2.imread(image_path)

preprocessed_image = preprocess_image(image)
extracted_text = pytesseract.image_to_string(image_path)
print(extracted_text)
# Out:
# Unless we can get e definite tne on him its
# hopelss....°SSRERMB wit turn up one day, yall se}
# Reddy said contdently. IP we plug away at He leads
# we have...""IP only the police would do something ..” Hugh
# Cried out in exasperation. “Tie put Crerything E kro
# befare them...’

# %%
from textblob import TextBlob
print(str(TextBlob(extracted_text).correct()))
# Out:
# Unless we can get e definite the on him its
# hopeless....°SSRERMB wit turn up one day, all se}
# Eddy said confidently. of we plug away at He leads
# we have...""of only the police would do something ..” Hugh
# Cried out in exasperation. “Lie put Everything E fro
# before them...’

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\jaish\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
import language_tool_python
import requests

my_tool = language_tool_python.LanguageTool('en-US')
def levenshtein(s1, s2):
    if len(s1) < len(s2):
        return levenshtein(s2, s1)

    if len(s2) == 0:
        return len(s1)

    previous_row = range(len(s2) + 1)
    for i, c1 in enumerate(s1):
        current_row = [i + 1]
        for j, c2 in enumerate(s2):
            insertions = previous_row[j + 1] + 1
            deletions = current_row[j] + 1       # than s2
            substitutions = previous_row[j] + (c1 != c2)
            current_row.append(min(insertions, deletions, substitutions))
        previous_row = current_row

    return previous_row[-1]

def spelling_accuracy(extracted_text):
    spell_corrected = TextBlob(extracted_text).correct()
    return ((len(extracted_text) - (levenshtein(extracted_text, spell_corrected)))/(len(extracted_text)+1))*100
    
def grammatical_accuracy(extracted_text):
    try:
        spell_corrected = TextBlob(extracted_text).correct()
        correct_text = my_tool.correct(spell_corrected)
        extracted_text_set = set(spell_corrected.split(" "))
        correct_text_set = set(correct_text.split(" "))
        n = max(len(extracted_text_set - correct_text_set),
                len(correct_text_set - extracted_text_set))
        return ((len(spell_corrected) - n) / (len(spell_corrected) + 1)) * 100
    except Exception as e:
        print("Error while calculating grammatical accuracy:", e)
        return 0  # Return 0 accuracy in case of error

spelling_accurac = spelling_accuracy(extracted_text)
grammatical_accurac = gramatical_accuracy(extracted_text)
print("Spelling Accuracy: ", spelling_accurac)
print("Grammatical Accuracy: ", grammatical_accurac)
percentage_correction = (100 - spelling_accurac + 100 - grammatical_accurac) 
print("Percentage of corrections:", percentage_correction)
# Out:
# Spelling Accuracy:  93.7956204379562
# Grammatical Accuracy:  99.63503649635037
# Percentage of corrections: 6.569343065693431

# %%
def process_images(directory, label):
    data = []
    for filename in os.listdir(directory):
        if filename.endswith(".jpg") or filename.endswith(".png"):  # Assuming images are jpg or png format
            image_path = os.path.join(directory, filename)
            image = cv2.imread(image_path)
            preprocessed_image = preprocess_image(image)
            extracted_text = pytesseract.image_to_string(preprocessed_image)
            spelling_acc = spelling_accuracy(extracted_text)
            grammatical_acc = grammatical_accuracy(extracted_text)
            percentage_correction = (100 - spelling_acc + 100 - grammatical_acc)
            data.append([spelling_acc, grammatical_acc, percentage_correction, label])
    return data

dyslexic_data = process_images(image_directory_dyslexic, 1)

non_dyslexic_data = process_images(image_directory_non_dyslexic, 0)

with open('data.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(['Spelling Accuracy', 'Grammatical Accuracy', 'Percentage of Correction', 'Label'])
    writer.writerows(dyslexic_data)
    writer.writerows(non_dyslexic_data)

print("Data has been written to data.csv file.")
# Out:
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Error while calculating grammatical accuracy: Error: Missing 'text' or 'data' parameter
# Data has been written to data.csv file.

# %%
import pandas as pd

data = pd.read_csv('data.csv')

filtered_data = data[(data['Spelling Accuracy'] != 0) & (data['Grammatical Accuracy'] != 0)]

filtered_data.to_csv('data.csv', index=False)

print("Records with 0 spelling and grammatical accuracy have been deleted from data.csv.")
# Out:
# Records with 0 spelling and grammatical accuracy have been deleted from data.csv.

# %% [markdown]
# # USING DIFFERENT CLASSIFIERS

# %%
import pandas as pd
import numpy as np
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
import seaborn as sns
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import pickle as pkl
import m2cgen

# %%
data = pd.read_csv('data.csv')

# %%
df = pd.read_csv('data.csv')
plt.figure(figsize=(6, 4)) 
plt.plot(df.index, df['percentage_of_correction'], marker='o', linestyle='-')
plt.xlabel('Sample Number')
plt.ylabel('Percentage of Corrections')
plt.title('Percentage of Corrections vs Sample Number')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('data.csv')
plt.figure(figsize=(6, 4)) 
plt.plot(df.index, df['spelling_accuracy'], marker='o', linestyle='-')
plt.xlabel('Sample Number')
plt.ylabel('Spelling Accuracy')
plt.title('Spelling Accuracy vs Sample Number')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('data.csv')
plt.figure(figsize=(6, 4)) 
plt.plot(df.index, df['grammatical_accuracy'], marker='o', linestyle='-')
plt.xlabel('Sample Number')
plt.ylabel('Gramatical Accuracy')
plt.title('Gramatical Accuracy vs Sample Number')
plt.grid(True)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv('data.csv')

fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(8, 6))

sns.barplot(x='Label', y='spelling_accuracy', data=df, ax=axes[0, 0])
axes[0, 0].set_title('Spelling Accuracy')

sns.barplot(x='Label', y='grammatical_accuracy', data=df, ax=axes[0, 1])
axes[0, 1].set_title('Grammatical Accuracy')

sns.barplot(x='Label', y='percentage_of_correction', data=df, ax=axes[1, 0])
axes[1, 0].set_title('Percentage of Corrections')

plt.tight_layout()
plt.show()

# %% [markdown]
# # Random Forest Classifier

# %%
X = data.drop(columns=['Label'])  
y = data['Label']  

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.27, random_state=42)

# %%
print((pd.concat([X_train, y_train], axis=1)).head())
# Out:
#     Spelling Accuracy  Grammatical Accuracy  Percentage of Correction  Label
# 11          86.811352             99.829060                 13.359588      1
# 66          78.838174             99.563319                 21.598507      0
# 67          89.378238             99.738220                 10.883542      0
# 31          82.638889             99.259259                 18.101852      1
# 75          90.666667             99.658703                  9.674630      0

# %%
print((pd.concat([X_test, y_test], axis=1)).head())
# Out:
#     Spelling Accuracy  Grammatical Accuracy  Percentage of Correction  Label
# 40          87.192118             99.748744                 13.059138      0
# 22          82.352941             94.117647                 23.529412      1
# 55          93.227991             99.772727                  6.999282      0
# 70          87.132353             99.625468                 13.242179      0
# 0           77.659574             98.901099                 23.439327      1

# %%
rf_classifier = RandomForestClassifier(random_state=42)

rf_classifier.fit(X_train, y_train)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = rf_classifier.predict(X_test)

print(rf_classifier.score(X_train, y_train))
print(rf_classifier.score(X_test, y_test))
# Out:
# 1.0
# 0.96

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[13  0]
#  [ 1 11]]

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Decision Tree Classifier

# %%
dt_classifier = DecisionTreeClassifier(random_state=42)

dt_classifier.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(random_state=42)

# %%
y_pred = dt_classifier.predict(X_test)

print(dt_classifier.score(X_train, y_train))
print(dt_classifier.score(X_test, y_test))
# Out:
# 1.0
# 0.96

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[13  0]
#  [ 1 11]]

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
# Out:
# <Axes: >

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

lr_classifier = LogisticRegression(random_state=42)
lr_classifier.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[24], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 lr_classifier = LogisticRegression(random_state=42)
# ----> 4 lr_classifier.fit(X_train, y_train)
#
# NameError: name 'X_train' is not defined

# %%
y_pred = lr_classifier.predict(X_test)

print(lr_classifier.score(X_train, y_train))
print(lr_classifier.score(X_test, y_test))
# Out:
# 0.8153846153846154
# 0.88

# %%
conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)
# Out:
# Confusion Matrix:
# [[13  0]
#  [ 3  9]]

# %%
sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
# Out:
# <Axes: >

# %%
from sklearn.svm import LinearSVC

svm_classifier = LinearSVC(dual=False, max_iter=10000, random_state=42)
svm_classifier.fit(X_train, y_train)

y_pred = svm_classifier.predict(X_test)

print(svm_classifier.score(X_train, y_train))
print(svm_classifier.score(X_test, y_test))

conf_matrix = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:")
print(conf_matrix)

sns.heatmap(confusion_matrix(y_test, y_pred), annot=True)
# Out:
# 0.8461538461538461
# 0.92
# Confusion Matrix:
# [[13  0]
#  [ 2 10]]
# <Axes: >
